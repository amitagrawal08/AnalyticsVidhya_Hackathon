# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import BernoulliNB
from sklearn.metrics import confusion_matrix

import numpy as np
import itertools
import matplotlib.pyplot as plt

def get_all_data():
    with open("train_2kmZucJ.csv", encoding="utf8") as csv_file:
        data = csv_file.read().split('\n')
        return data
    
def preprocessing_data(data):
    processing_data = []
    for single_data in data:
        if len(single_data.split(",")) == 3:
            processing_data.append(single_data.split(","))
    return processing_data

all_data=get_all_data()
processing_data=preprocessing_data(all_data)
print(processing_data)


def training_step(data, vectorizer):
    training_text = [data[2] for data in data]
    training_result = [data[1] for data in data]
    training_text = vectorizer.fit_transform(training_text)
    return BernoulliNB().fit(training_text, training_result)

vectorizer = CountVectorizer(binary = 'true')
classifier = training_step(processing_data, vectorizer)
result = classifier.predict(vectorizer.transform(["Happy"]))
result[0]

def analyse_text(classifier, vectorizer, text):
    return text, classifier.predict(vectorizer.transform([text]))

def print_result(result):
    text, analysis_result = result
    print_text = "Positive" if analysis_result[0] == '1' else "Negative"
    print(text, ":", print_text)

for i in processing_data:
    print_result(analyse_text(classifier, vectorizer, i[2]))
    print(i[0])
# Out:
# [['id', 'label', 'tweet'], ['1', '0', '#fingerprint #Pregnancy Test https://goo.gl/h1MfQV #android #apps #beautiful #cute #health #igers #iphoneonly #iphonesia #iphone'], ['2', '0', 'Finally a transparant silicon case ^^ Thanks to my uncle :) #yay #Sony #Xperia #S #sonyexperias… http://instagram.com/p/YGEt5JC6JM/'], ['3', '0', 'We love this! Would you go? #talk #makememories #unplug #relax #iphone #smartphone #wifi #connect... http://fb.me/6N3LsUpCu'], ['4', '0', "I'm wired I know I'm George I was made that way ;) #iphone #cute #daventry #home http://instagr.am/p/Li_5_ujS4k/"], ['5', '1', "What amazing service! Apple won't even talk to me about a question I have unless I pay them $19.95 for their stupid support!"], ['6', '1', 'iPhone software update fucked up my phone big time Stupid iPhones'], ['7', '0', 'Happy for us .. #instapic #instadaily #us #sony #xperia #xperiaZ https://instagram.com/p/z9qGfWlvj7/'], ['8', '0', 'New Type C charger cable #UK http://www.ebay.co.uk/itm/-/1125986
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import BernoulliNB
import pandas as pd
import csv

train_tweet_data=pd.read_csv("train_2kmZucJ.csv")
train_tweet_data.columns

def training_step(data, vectorizer):
    training_text = data['tweet']
    training_result = data['label']
    training_id = data['id']
    training_text = vectorizer.fit_transform(training_text)
    return BernoulliNB().fit(training_text, training_result, training_id)

vectorizer = CountVectorizer(binary = 'true')
classifier = training_step(train_tweet_data, vectorizer)

def analyse_text(classifier, vectorizer, text, index):
    return index, text, classifier.predict(vectorizer.transform([text])), 

for result in train_tweet_data['tweet']:
    index, text, train_result = analyse_text(classifier, vectorizer, result)
    print(text, ":", train_result)

## Test and get the result of provided test data
    
test_tweet_data=pd.read_csv("test_oJQbWVk.csv")
test_tweet_data.columns

outputfile_index=[]
outputfile_label=[]
outputfile_text=[]

for result2 in test_tweet_data['tweet']:
    for index in test_tweet_data['id']:
        outputfile_index.append(index)
    text, test_result = analyse_text(classifier, vectorizer, result2['tweet'])
        
    outputfile_index
    output_label = str(test_result)
    output=output_index,output_label
    print(output_index, ":", output_label)
    outputfile.append(output)
    df1= pd.DataFrame(data=outputfile, columns=['id','label'])
    #df1.reset_index(level=None,drop=True, inplace=True)
    df1.to_csv('sample_output.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-0c5a3c25dac5> in <module>
#      33
#      34 for result2 in test_tweet_data['tweet']:
# ---> 35     text, test_result = analyse_text(classifier, vectorizer, result2['tweet'])
#      36     for index in test_tweet_data['id']:
#      37         outputfile_index.append(index)
#
# TypeError: string indices must be integers

# %%
len(test_tweet_data)
# Out:
# 1953

# %%
test_tweet_data=pd.read_csv("test_oJQbWVk.csv")
test_tweet_data.columns

outputfile=[]

#for result2 in test_tweet_data['id']:
#    outputfile.append(result2)
#outputfile[2]

# %%
df1.reset_index?

# %%
for line in test_tweet_data:
    print(line)
# Out:
# id
# tweet

# %%
aaaa=test_tweet_data[1:2]
str(aaaa)
# Out:
# '     id                                              tweet\n1  7922  currently shitting my fucking pants. #apple #i...'

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import BernoulliNB
import pandas as pd
import csv

train_tweet_data=pd.read_csv("train_2kmZucJ.csv")
train_tweet_data.columns

def training_model(data, vectorizer):
    training_text = data['tweet']
    training_result = data['label']
    training_id = data['id']
    training_text = vectorizer.fit_transform(training_text)
    return BernoulliNB().fit(training_text, training_result, training_id)

vectorizer = CountVectorizer(binary = 'true')
classifier = training_model(train_tweet_data, vectorizer)

def analyse_text(classifier, vectorizer, text, index):
    return index, text, classifier.predict(vectorizer.transform([text])), 

trainfile_index=[]
trainfile_label=[]
trainfile_text=[]

for index in train_tweet_data['id']:
    trainfile_index.append(index)
for text in train_tweet_data['tweet']:
    trainfile_text.append(text)
i=0
    
while i < len(trainfile_index):
    index, text, train_result = analyse_text(classifier, vectorizer, trainfile_text[i], trainfile_index[i])
    #print(index, ":", text, ":", train_result)
    i+=1


## Test and get the result of provided test data
    
test_tweet_data=pd.read_csv("test_oJQbWVk.csv")
test_tweet_data.columns

outputfile_index=[]
outputfile=[]
outputfile_text=[]

for index in test_tweet_data['id']:
    outputfile_index.append(index)
for text in test_tweet_data['tweet']:
    outputfile_text.append(text)

i=0
while i < len(outputfile_index):
    index, text, test_label = analyse_text(classifier, vectorizer, outputfile_text[i], outputfile_index[i])
    #print(index, ":", text, ":", test_label)
    i+=1
    output_label = test_label[0]
    output=index,output_label
    print(index, ":", output_label)
    outputfile.append(output)

df1= pd.DataFrame(data=outputfile, columns=['id','label'])
df1.to_csv('sample_output.csv', index=False)
# Out:
# 7921 : 1
# 7922 : 1
# 7923 : 1
# 7924 : 0
# 7925 : 1
# 7926 : 0
# 7927 : 1
# 7928 : 0
# 7929 : 1
# 7930 : 0
# 7931 : 0
# 7932 : 0
# 7933 : 0
# 7934 : 0
# 7935 : 0
# 7936 : 0
# 7937 : 0
# 7938 : 1
# 7939 : 1
# 7940 : 0
# 7941 : 0
# 7942 : 0
# 7943 : 1
# 7944 : 0
# 7945 : 1
# 7946 : 1
# 7947 : 0
# 7948 : 0
# 7949 : 1
# 7950 : 0
# 7951 : 1
# 7952 : 0
# 7953 : 0
# 7954 : 0
# 7955 : 0
# 7956 : 1
# 7957 : 1
# 7958 : 0
# 7959 : 0
# 7960 : 0
# 7961 : 0
# 7962 : 0
# 7963 : 0
# 7964 : 1
# 7965 : 0
# 7966 : 0
# 7967 : 0
# 7968 : 0
# 7969 : 1
# 7970 : 0
# 7971 : 1
# 7972 : 0
# 7973 : 0
# 7974 : 0
# 7975 : 0
# 7976 : 1
# 7977 : 1
# 7978 : 0
# 7979 : 0
# 7980 : 1
# 7981 : 0
# 7982 : 0
# 7983 : 0
# 7984 : 0
# 7985 : 0
# 7986 : 0
# 7987 : 1
# 7988 : 1
# 7989 : 0
# 7990 : 1
# 7991 : 0
# 7992 : 0
# 7993 : 1
# 7994 : 0
# 7995 : 1
# 7996 : 0
# 7997 : 1
# 7998 : 0
# 7999 : 0
# 8000 : 1
# 8001 : 0
# 8002 : 1
# 8003 : 0
# 8004 : 1
# 8005 : 0
# 8006 : 1
# 8007 : 0
# 8008 : 0
# 8009 : 0
# 8010 : 0
# ...

# %%
outputfile_index=[]
outputfile=[]
outputfile_text=[]
for index in test_tweet_data['id']:
    outputfile_index.append(index)
for text in test_tweet_data['tweet']:
    outputfile_text.append(text)

len(outputfile_index)
len(outputfile_text)
i=0

while i < len(outputfile_index):
    print (outputfile_index[i], outputfile_text[i])
    i+=1
    output_label = str(test_result)
    output=output_index,output_label
    print(output_index, ":", output_label)
    outputfile.append(output)
    df1= pd.DataFrame(data=outputfile, columns=['id','label'])
    #df1.reset_index(level=None,drop=True, inplace=True)
    df1.to_csv('sample_output.csv', index=False)
#    text, test_result = analyse_text(classifier, vectorizer, result2['tweet'])
# Out:
# I hate the new #iphone upgrade. Won't let me download apps. #ugh #apple sucks 7921
# currently shitting my fucking pants. #apple #iMac #cashmoney #raddest #swagswagswag http://instagr.am/p/UUIS0bIBZo/ 7922
# I'd like to puts some CD-ROMS on my iPad, is that possible?' — Yes, but wouldn't that block the screen? 7923
# My ipod is officially dead. I lost all my pictures and videos from the 1D and 5sos concert,and from Vet Camp #hatinglife #sobbing 7924
# Been fighting iTunes all night! I only want the music I $&@*# paid for 7925
# #Repost @getbakednfried with repostapp ・・・ to announce we will have our #apple #bourbon… https://www.instagram.com/p/BK5okHOgWSS/ 7926
# This new apple software update is really doing things to my phone. Bad things apple 7927
# BABY #iPhone #iphone6s #gold #new #apple #appleisbest #64GB #gegönnt #aaaaah https://www.instagram.com/p/BAUx8eQtKez/ 7928
# ...

# %%
import pandas as pd

# %%
data = pd.read_csv("train_2kmZucJ.csv")
print(data.head(2))
# Out:
#    id  label                                              tweet
# 0   1      0  #fingerprint #Pregnancy Test https://goo.gl/h1...
# 1   2      0  Finally a transparant silicon case ^^ Thanks t...

# %%
import nltk

# %%
dataset = pd.read_csv("train_2kmZucJ.csv")
dataset.head()
# Out:
#    id  label                                              tweet
# 0   1      0  #fingerprint #Pregnancy Test https://goo.gl/h1...
# 1   2      0  Finally a transparant silicon case ^^ Thanks t...
# 2   3      0  We love this! Would you go? #talk #makememorie...
# 3   4      0  I'm wired I know I'm George I was made that wa...
# 4   5      1  What amazing service! Apple won't even talk to...

# %%
dataset.isnull().sum()
# Out:
# id       0
# label    0
# tweet    0
# dtype: int64

# %%
pat1 = r'@[A-Za-z0-9]+' # this is to remove any text with @....
pat2 = r'https?://[A-Za-z0-9./]+'  # this is to remove the urls
combined_pat = r'|'.join((pat1, pat2)) 
pat3 = r'[^a-zA-Z]' # to remove every other character except a-z & A-Z
combined_pat2 = r'|'.join((combined_pat,pat3)) # we combine pat1, pat2 and pat3 to pass it in the cleaning steps

# %%
combined_pat2
# Out:
# '@[A-Za-z0-9]+|https?://[A-Za-z0-9./]+|[^a-zA-Z]'

# %%
len(dataset['tweet'])
# Out:
# 7920

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
cleaned_tweets = []

# %%
for i in range(0, len(dataset['tweet'])) :
    tweets = re.sub(combined_pat2,' ',dataset['tweet'][i])
    tweets = tweets.lower()
    tweets = tweets.split()
    tweets = [ps.stem(word) for word in tweets if not word in set(stopwords.words('english'))]
    tweets = ' '.join(tweets)
    cleaned_tweets.append(tweets)

# %%
cleaned_tweets

# %%
dataset.columns
# Out:
# Index(['id', 'label', 'tweet', 'cleaned_tweets'], dtype='object')

# %%
dataset['cleaned_tweets'] = cleaned_tweets

# %%
dataset['cleaned_tweets']
# Out:
# 0       fingerprint pregnanc test android app beauti c...
# 1       final transpar silicon case thank uncl yay son...
# 2       love would go talk makememori unplug relax iph...
# 3       wire know georg made way iphon cute daventri h...
# 4       amaz servic appl even talk question unless pay...
# 5       iphon softwar updat fuck phone big time stupid...
# 6       happi us instap instadaili us soni xperia xperiaz
# 7       new type c charger cabl uk bay amazon etsi new...
# 8       bout go shop listen music iphon justm music li...
# 9       photo fun selfi pool water soni camera picofth...
# 10      hey appl make new ipod dont make new color inc...
# 11      ha heavi machineri need realli drop ball desig...
# 12      contempl give iphon bandwagon simpli cellcom n...
# 13      made anoth crazi purchas lol theori work hard ...
# 14      louis batteri pain charg overnight lunchtim ba...
# 15      deepellum toward downtown dalla bigd saturday ...
# ...

# %%
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()
for tweet in cleaned_tweets[:10]:
    print(tweet)
    s = sia.polarity_scores(tweet)
    for k in sorted(s):
        print('{0}: {1}, '.format(k, s[k]), end='')
        print()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\eamiagr\AppData\Roaming\nltk_data...
# fingerprint pregnanc test android app beauti cute health iger iphoneonli iphonesia iphon
# compound: 0.4588,
# neg: 0.0,
# neu: 0.786,
# pos: 0.214,
# final transpar silicon case thank uncl yay soni xperia sonyexperia
# compound: 0.7096,
# neg: 0.0,
# neu: 0.576,
# pos: 0.424,
# love would go talk makememori unplug relax iphon smartphon wifi connect
# compound: 0.7964,
# neg: 0.0,
# neu: 0.559,
# pos: 0.441,
# wire know georg made way iphon cute daventri home uj k
# compound: 0.4588,
# neg: 0.0,
# neu: 0.75,
# pos: 0.25,
# amaz servic appl even talk question unless pay stupid support
# compound: -0.2732,
# neg: 0.331,
# neu: 0.483,
# pos: 0.186,
# iphon softwar updat fuck phone big time stupid iphon
# compound: -0.7845,
# neg: 0.496,
# neu: 0.504,
# pos: 0.0,
# happi us instap instadaili us soni xperia xperiaz
# compound: 0.0,
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# ...

# %%
def findpolarity(data):
    sid = SentimentIntensityAnalyzer()
    polarity = sid.polarity_scores(data)
    if(polarity['compound'] >= 0.2):  
        sentiment = 1
    if(polarity['compound'] <= -0.2):
        sentiment = -1 
    if(polarity['compound'] < 0.2 and polarity['compound'] >-0.2):
        sentiment = 0     
    return(sentiment)
findpolarity(cleaned_tweets[0])
# Out:
# 1

# %%
sentiment = []
for i in range(0, len(cleaned_tweets)):
    s = findpolarity(cleaned_tweets[i])
    sentiment.append(s)

# %%
len(sentiment)
# Out:
# 7920

# %%
len(cleaned_tweets)
# Out:
# 7920

# %%
tweet_sentiment = pd.DataFrame()
tweet_sentiment['cleaned_tweets'] = cleaned_tweets
tweet_sentiment['sentiment'] = sentiment

# %%
tweet_sentiment.to_csv('tweet_sentiment.csv', index=False)

# %%
tweet_sentiment.shape[0]
# Out:
# 7920

# %%
positive_tweet = []
negative_tweet = []
neutral_tweet = []

for i in range(0, tweet_sentiment.shape[0]):
    if tweet_sentiment['sentiment'][i] == 0:
        neutral_tweet.append(tweet_sentiment['cleaned_tweets'][i])
    elif tweet_sentiment['sentiment'][i] == 1:
        positive_tweet.append(tweet_sentiment['cleaned_tweets'][i])
    elif tweet_sentiment['sentiment'][i] == -1:
        negative_tweet.append(tweet_sentiment['cleaned_tweets'][i])

# %%
negative_tweet[:10]
# Out:
# ['amaz servic appl even talk question unless pay stupid support',
#  'iphon softwar updat fuck phone big time stupid iphon',
#  'new type c charger cabl uk bay amazon etsi new year rob cross tobi young evemun mcmafia taylor spectr newyear start recip technolog samsunggalaxi iphonex pic twitter com pjiwq wtc',
#  'hey appl make new ipod dont make new color inch thinner make crash everi five fuckin minit',
#  'contempl give iphon bandwagon simpli cellcom new android depress idontwantto',
#  'louis batteri pain charg overnight lunchtim batteri dead hateorang',
#  'appl store gunna c screen monday ur fuck appl store fuckingpiss',
#  'new ipod four day button back broke accident hit',
#  'iphon screen goe complet black keep get text day fuck check appl thiphon',
#  'ipod mess done noth myloss appl']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from wordcloud import WordCloud, STOPWORDS
stopwords = set(STOPWORDS)

def show_wordcloud(data, title = None):
    wordcloud = WordCloud(
        background_color='black',
        stopwords=stopwords,
        max_words=200,
        max_font_size=40, 
        scale=3,
        random_state=1 # chosen at random by flipping a coin; it was heads
    ).generate(str(data))

    fig = plt.figure(1, figsize=(12, 12))
    plt.axis('off')
    if title: 
        fig.suptitle(title, fontsize=20)
        fig.subplots_adjust(top=2.3)

    plt.imshow(wordcloud)
    plt.show()

show_wordcloud(positive_tweet)
show_wordcloud(neutral_tweet)
show_wordcloud(negative_tweet)

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()
X = cv.fit_transform(tweet_sentiment['cleaned_tweets']).toarray()
y = tweet_sentiment['sentiment']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.15, random_state = 0)

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
score = accuracy_score(y_test, y_pred)

# %%
cm
# Out:
# array([[102,  58,  31],
#        [139, 218,  85],
#        [ 74, 186, 295]], dtype=int64)

# %%
score
# Out:
# 0.5176767676767676
